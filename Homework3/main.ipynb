# %%
# %load_ext autoreload
# %autoreload 2

# %%
import json

import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans, AffinityPropagation, MeanShift, SpectralClustering, AgglomerativeClustering, DBSCAN, Birch
from sklearn.mixture import GaussianMixture
from sklearn.metrics import normalized_mutual_info_score

# %%
# read data
with open('./Tweets.txt') as f:
    data = [json.loads(l[:-1]) for l in f.readlines()]
data
# Out:
# [{'text': 'brain fluid buildup delay giffords rehab', 'cluster': 37},
#  {'text': 'trailer talk week movie rite mechanic week opportunity',
#   'cluster': 14},
#  {'text': 'rnc appoints chairman tampa convention effort visit tampa republican nati tampa fl',
#   'cluster': 100},
#  {'text': 'gbagbo camp futile cut ivory coast economy', 'cluster': 110},
#  {'text': 'chinese president lost translation powerful leader meet expect tran',
#   'cluster': 61},
#  {'text': 'england fishing community current management system broken edf',
#   'cluster': 60},
#  {'text': 'protest reform start yemen hundred anti government protester gathered sanaa',
#   'cluster': 79},
#  {'text': 'stuxnet lead chernobyl russian', 'cluster': 83},
#  {'text': 'iphone share smartphones phone', 'cluster': 81},
#  {'text': 'uploaded youtube video nba final lakers celtic game memory highlig',
#   'cluster': 67},
#  {'text': 'feed epic sci fi car ad kia optimum super bowl commercial video trendhunter supe',
#   'cluster': 99},
#  {'text': 'naughty facebook started sharing personal detail site day turn fb',
#   'cluster': 95},
#  {'text': 'super bowl commercial', 'cluster': 99},
#  {'text': 'bruce will fave kardashian lol', 'cluster': 72},
#  {'text': 'attack journalist escalate egypt', 'cluster': 66},
#  {'text': 'keith olbermann join current tv report', 'cluster': 30},
#  {'text': 'opinion christina sounded amazing super bowl america making big deal',
#   'cluster': 75},
#  {'text': 'sundance day strange celebrity encounter steve carell elijah wood full day sundanc',
#   'cluster': 96},
#  {'text': 'acai berry supplement weight loss associated content heard oprah win',
#   'cluster': 55},
#  {'text': 'finished watching black swan twisted mental strain take embrace role natalie portman incredible',
#   'cluster': 101},
#  {'text': 'hot air breaking rahm ballot tcot lt state totally corrupt',
#   'cluster': 21},
#  {'text': 'charlie sheen abuse', 'cluster': 68},
#  {'text': 'music featured motorola xoom super bowl commercial', 'cluster': 99},
#  {'text': 'rite movie review fan movie deal battle good evil', 'cluster': 14},
#  {'text': 'potential replacement steve job', 'cluster': 106},
#  {'text': 'yemen president signal won stay freedomwar egypt jan syria feb',
#   'cluster': 79},
#  {'text': 'debt settlement lawyer debt settlement easier lawyer day debt settlement beco',
#   'cluster': 74},
#  {'text': 'aguilera repeat national anthem ap ap christina aguilera flubbed belted',
#   'cluster': 75},
#  {'text': 'skipped romanian crew journalist threatened attacked detained reporting egypt',
#   'cluster': 66},
#  {'text': 'loss weight acai berry capsule benefit', 'cluster': 55},
#  {'text': 'pew internet online american social networking twitter politics campaign internet',
#   'cluster': 45},
#  {'text': 'tbf flw outdooors introduce national high school fishing program national high school fishing program',
#   'cluster': 60},
#  {'text': 'fucking awesome jesse jesse ventura slam tsa lawsuit',
#   'cluster': 25},
#  {'text': 'king speech awarded best ensemble cast screen actor guild award',
#   'cluster': 88},
#  {'text': 'charge fee saltwater fishing license', 'cluster': 60},
#  {'text': 'bottega veneta teal turquoise knot intrecciato snakeskin clutch',
#   'cluster': 46},
#  {'text': 'baked slow cooker chicken crockpotrecipes', 'cluster': 87},
#  {'text': 'fake snow storm white stripe officially call quits', 'cluster': 17},
#  {'text': 'chrysler air super bowl commercial', 'cluster': 99},
#  {'text': 'kid set college time fill fafsa', 'cluster': 97},
#  {'text': 'funny happened aguilera repeat national anthem yahoo news',
#   'cluster': 75},
#  {'text': 'hollywood director honor king speech reuters', 'cluster': 88},
#  {'text': 'kung pao chicken recipe', 'cluster': 87},
#  {'text': 'giffords rocky road recovery health news', 'cluster': 37},
#  {'text': 'complete list super bowl commercial advertiser youtube',
#   'cluster': 99},
#  {'text': 'senator avoiding tea party caucus', 'cluster': 103},
#  {'text': 'watch volkswagen superbowl commercial youtube ad blitz channel escarabaajoos',
#   'cluster': 99},
#  {'text': 'washington legislature wade immigration debate oregonlive summary requires employe verify',
#   'cluster': 82},
#  {'text': 'te boozing news starbucks huge trenta cup hold entire bottle wine',
#   'cluster': 62},
#  {'text': 'carney obama press secretary', 'cluster': 44},
#  {'text': 'kardashians pier morgan stupid answer question perfect',
#   'cluster': 72},
#  {'text': 'chavez mark year office venezuelan president hugo chavez mark year power promising press',
#   'cluster': 56},
#  {'text': 'rite safe horror film devil time plain dealer', 'cluster': 14},
#  {'text': 'chipotle fire hundred immigration raid immigration probe forced mexican chain chipotle fire',
#   'cluster': 80},
#  {'text': 'beetle commercial creative superbowl great teaser', 'cluster': 99},
#  {'text': 'yemen thousand protest government worldnomads travelsafety',
#   'cluster': 79},
#  {'text': 'going amazing constitutional showdown reach supreme court',
#   'cluster': 22},
#  {'text': 'aquarium fish aquarium success good common sense will fir',
#   'cluster': 60},
#  {'text': 'justice extend protection workplace retaliation supreme court ruled employer sued',
#   'cluster': 89},
#  {'text': 'white house press secretary jay carney', 'cluster': 44},
#  {'text': 'oscar reaction guess king speech', 'cluster': 88},
#  {'text': 'cnn hack facebook unlocks security facebook adding security feature pa',
#   'cluster': 95},
#  {'text': 'nfl concussion people survey wix jsquared concussion',
#   'cluster': 84},
#  {'text': 'national guard called chicago snow storm woow snow chill people',
#   'cluster': 57},
#  {'text': 'loooooooooooove ncis', 'cluster': 77},
#  {'text': 'weight loss diet plan acai juice equal nutritional claim acai',
#   'cluster': 55},
#  {'text': 'traffic depot update oceanside green light red light camera ticket traffic',
#   'cluster': 64},
#  {'text': 'christina aguilera mess national anthem start super bowl xlv',
#   'cluster': 75},
#  {'text': 'definitely forward superbowl commercial year esp steve martin cameo',
#   'cluster': 99},
#  {'text': 'acai berry diet succeed hoodia gordonii site acai berry cultivated acai palm',
#   'cluster': 55},
#  {'text': 'hugo chavez apologizes venezuelan people ahead election',
#   'cluster': 56},
#  {'text': 'fishing news banner website', 'cluster': 60},
#  {'text': 'keith olbermann join current tv report keith olbermann controversial liberal pundit ho',
#   'cluster': 30},
#  {'text': 'chicago rahm emanuel ballot', 'cluster': 21},
#  {'text': 'tanning iced coffee tazo iced tea hello trenta', 'cluster': 62},
#  {'text': 'watching kourtney kim khloe loving waiting forever', 'cluster': 72},
#  {'text': 'vincent tabak appears court charged murder', 'cluster': 86},
#  {'text': 'casserole recipe bruschetta chicken bake submitted heather simple creative chicken meal mimic',
#   'cluster': 87},
#  {'text': 'honor epic fail national anthem top ten list time worst',
#   'cluster': 75},
#  {'text': 'info topic fish tank heater aquarium stuff technorati tag aquarium heater aquariu',
#   'cluster': 60},
#  {'text': 'grilled chicken tomato salad', 'cluster': 87},
#  {'text': 'today read concerned gasland movie stand set record straight',
#   'cluster': 109},
#  {'text': 'king speech top film producer award ap ap king speech claimed crown be',
#   'cluster': 88},
#  {'text': 'sag prediction award tracker hmmmm', 'cluster': 88},
#  {'text': 'kia spent lot money optimum superbowl commercial', 'cluster': 99},
#  {'text': 'doritos commercial raising dead best night superbowl nfl',
#   'cluster': 99},
#  {'text': 'idf intelligence chief iran nuclear bomb year haaretz',
#   'cluster': 73},
#  {'text': 'yeah don csis nciss enjoy mentalist', 'cluster': 77},
#  {'text': 'uk robert kubica injured rally accident italian polish medium',
#   'cluster': 11},
#  {'text': 'breaking news king speech take top honor hollywood actor honor best sunday night annual screen ac',
#   'cluster': 88},
#  {'text': 'obamacare reagan appointed federal district judge florida ruled key portion obama',
#   'cluster': 22},
#  {'text': 'st tunisia egypt yemen', 'cluster': 79},
#  {'text': 'best superbowl commercial year chrysler comeback', 'cluster': 99},
#  {'text': 'horrible journalist attacked detained egypt yahoo news',
#   'cluster': 66},
#  {'text': 'list journalist hurt harassed egypt', 'cluster': 66},
#  {'text': 'famous facebook flip flop social networking goliath number hasty move year',
#   'cluster': 95},
#  {'text': 'yikes list journalist attacked egypt hour abc news', 'cluster': 66},
#  {'text': 'lady press ahead fitness campaign daily caller obama tell abc good morning america',
#   'cluster': 65},
#  {'text': 'judge rule obama health care law', 'cluster': 22},
#  {'text': 'watch christina aguilera screw national anthem super bowl post',
#   'cluster': 75},
#  {'text': 'acai berry powder content health weight loss hard figure',
#   'cluster': 55},
#  {'text': 'facebook privacy setting user', 'cluster': 95},
#  {'text': 'taco bell beef convenience cost', 'cluster': 20},
#  {'text': 'jordan thousand protest demand pm step wave mass protest arab spread opposition supporter',
#   'cluster': 38},
#  {'text': 'yap palau sport fishing promotional sport fishing video produced video rating',
#   'cluster': 60},
#  {'text': 'court third party bias protection broad washington jan upi supreme court ruled unanimously',
#   'cluster': 89},
#  {'text': 'yell cast jr hartley ad digital era author search fly fishing book dj hunt book read',
#   'cluster': 60},
#  {'text': 'boatsshopping fishing headline oklahoma metro trout fishing pond instructional clinic pave exciting winter angling html',
#   'cluster': 60},
#  {'text': 'three ton striped bass seized illegal fishing net', 'cluster': 60},
#  {'text': 'federal judge strike health care reform call insurance purchase mandate aba journal',
#   'cluster': 22},
#  {'text': 'love khloe kardashian', 'cluster': 72},
#  {'text': 'fighter king speech lead nominee tonight sag award beverly hill courier',
#   'cluster': 88},
#  {'text': 'check video christina aguilera super bowl national anthem mistake mess err',
#   'cluster': 75},
#  {'text': 'murray djokovic happened', 'cluster': 71},
#  {'text': 'pressure grows myanmar sanction call growing western sanction myanmar',
#   'cluster': 110},
#  {'text': 'poll gop catch dems social medium', 'cluster': 45},
#  {'text': 'nobel war prize wikileaks nuke fired cablegate wikileaks assange anonymous',
#   'cluster': 12},
#  {'text': 'bbc news police lose officer', 'cluster': 51},
#  {'text': 'lololol doritos pepsi max killing superbowl commercial',
#   'cluster': 99},
#  {'text': 'federal judge healthcare law', 'cluster': 22},
#  {'text': 'king speech notch top director award movie running darren aronofsky',
#   'cluster': 88},
#  {'text': 'yummy recipe tuesday chicken fricasse', 'cluster': 87},
#  {'text': 'secret natural weight loss food acai berry benefit', 'cluster': 55},
#  {'text': 'job wrong place memo president dear president state union add',
#   'cluster': 32},
#  {'text': 'employment gaining speed jobless rate', 'cluster': 26},
#  {'text': 'ten thousand yemeni protest sanaa ten thousand yemeni staged day rage calling',
#   'cluster': 79},
#  {'text': 'awful watched don text drive video driving class', 'cluster': 104},
#  {'text': 'netgear bos astonishing attack steve job', 'cluster': 106},
#  {'text': 'bronco christina aguilera flub national anthem kmgh denver',
#   'cluster': 75},
#  {'text': 'governor proposes sweeping cut funding york school medicaid program slashed',
#   'cluster': 19},
#  {'text': 'check article fox news sideline test detect concussion minute',
#   'cluster': 84},
#  {'text': 'eye will definetely glued tv screen love kardashians',
#   'cluster': 72},
#  {'text': 'don text drive pledge', 'cluster': 104},
#  {'text': 'fishing technique fishing maine surf fishing striped bass',
#   'cluster': 60},
#  {'text': 'tsa unveils body scanner software doesn naked alternet',
#   'cluster': 25},
#  {'text': 'oscar king speech haven black swan', 'cluster': 88},
#  {'text': 'teen creates anti bullying school program', 'cluster': 90},
#  {'text': 'bedbug rapidly evolving fight pesticide tech news', 'cluster': 52},
#  {'text': 'super bowl commercial report card ranking winner loser bleacher report',
#   'cluster': 99},
#  {'text': 'fast food caught immigration crosshairs reuters', 'cluster': 80},
#  {'text': 'vice president communication director jay carney named white house press secretary',
#   'cluster': 44},
#  {'text': 'high court third party sue retaliation case', 'cluster': 89},
#  {'text': 'kold aguilera repeat national anthem', 'cluster': 75},
#  {'text': 'volkswagon commercial superbowl', 'cluster': 99},
#  {'text': 'deadbedbugs fact bed bug cover', 'cluster': 52},
#  {'text': 'gross taco bell sued bogus beef', 'cluster': 20},
#  {'text': 'great bbc piece summarising unrest north africa middle east',
#   'cluster': 79},
#  {'text': 'sidney crosby concussion rule change braine hope pray doesn sight',
#   'cluster': 84},
#  {'text': 'charlie sheen leaf hospital medical emergency', 'cluster': 68},
#  {'text': 'trenta cup hold entire bottle wine wrong', 'cluster': 62},
#  {'text': 'healthy school food pay save attention going', 'cluster': 102},
#  {'text': 'post financial aid college lt gt financial advice lt gt popular lt gt lt gt',
#   'cluster': 97},
#  {'text': 'teacher talking texting driving haaayy', 'cluster': 104},
#  {'text': 'financial aid help woman school hispanic scholarship',
#   'cluster': 97},
#  {'text': 'mubarak silencing voice egypt journalist targeted read jan tahrir',
#   'cluster': 66},
#  {'text': 'video favorite superbowl commercial cute', 'cluster': 99},
#  {'text': 'remember alex brown', 'cluster': 104},
#  {'text': 'enjoyed vw beetle commercial superbowl favorite', 'cluster': 99},
#  {'text': 'join campaign texting driving save life future will help',
#   'cluster': 104},
#  {'text': 'crazy lake shore drive downtown chicago shut', 'cluster': 57},
#  {'text': 'blog post potential replacement steve job apple', 'cluster': 106},
#  {'text': 'acai berry chocolate tasting weight loss diet plan adi news scientifically prov',
#   'cluster': 55},
#  {'text': 'red cabbage add color noodle salad soba salad chicken cabbage',
#   'cluster': 87},
#  {'text': 'boosting america fashion', 'cluster': 91},
#  {'text': 'news workshop preventing bullying positive behavior support school',
#   'cluster': 90},
#  {'text': 'yemen president won election', 'cluster': 79},
#  {'text': 'best buy launch electronics buy program ap ap timing shopping gadget',
#   'cluster': 85},
#  {'text': 'force strong great ad volkswagon superbowl commercial',
#   'cluster': 99},
#  {'text': 'dragon cute drinking cola superbowl cocacola commercial',
#   'cluster': 99},
#  {'text': 'latest headline king speech lead oscar field british star colin firth helena bonham carter nominate',
#   'cluster': 88},
#  {'text': 'klassy breeze music blog black eyed aguilera love', 'cluster': 75},
#  {'text': 'journalist social medium report egyptian demonstration journalist',
#   'cluster': 45},
#  {'text': 'hooper earns top dga prize king speech hooper won david fincher social network',
#   'cluster': 88},
#  {'text': 'ap maker academy award favorite social network king speech competi',
#   'cluster': 88},
#  {'text': 'congrats novak djokovic played brilliant tennis definitely deserve title',
#   'cluster': 71},
#  {'text': 'breaknews yemen street day rage yemeni filled street sanaa',
#   'cluster': 79},
#  {'text': 'protest start yemen despite concession president hundred anti government protest',
#   'cluster': 79},
#  {'text': 'al jazeera journalist detained cairo police hotel room equipment confiscated jan',
#   'cluster': 66},
#  {'text': 'update michael steele resigns rnc', 'cluster': 100},
#  {'text': 'egypt yemen demand change government well gt news tcot',
#   'cluster': 79},
#  {'text': 'orange student dish school lunch white house chef orlando sentinel fl schoollunch letsmove',
#   'cluster': 102},
#  {'text': 'successful ice fishing perch depth finder successful ice',
#   'cluster': 60},
#  {'text': 'acai berry weight loss diet plan healthy weight reduction number diet plan',
#   'cluster': 55},
#  {'text': 'thought beef lawsuit pr response', 'cluster': 20},
#  {'text': 'chris hemsworth lead celebrity storm tao sundance ministry appreciates sundance film festival founder',
#   'cluster': 96},
#  {'text': 'chipotle face ice inspection state reuters reuters chipotle mexican grill',
#   'cluster': 80},
#  {'text': 'love kim kardashian ur hot wooohoooo lol', 'cluster': 72},
#  {'text': 'ten thousand march yemen president sanaa yemen ten thousand lukewilliamss',
#   'cluster': 79},
#  {'text': 'best commercial super bowl imported detroit best', 'cluster': 99},
#  {'text': 'late night time watch crime solving tv ncis csi sky looooove',
#   'cluster': 77},
#  {'text': 'doritos commercial vote funniest superbowl commercial',
#   'cluster': 99},
#  {'text': 'budweiser wild west tiny dancer commercial definitely favorite superbowl',
#   'cluster': 99},
#  {'text': 'best deal fishing bait lure ebay best price', 'cluster': 60},
#  {'text': 'fallon follow tip save energy included site tip will help beat hig',
#   'cluster': 27},
#  {'text': 'uk foreign office urgently checking briton caught explosion uk news',
#   'cluster': 36},
#  {'text': 'government spending cut leave north east forestry commission base saveourforests',
#   'cluster': 51},
#  {'text': 'starbucks trenta hold entire bottle wine people cougartown',
#   'cluster': 62},
#  {'text': 'interested giffords improves watch hour tv gabrielle giffords watched hour television',
#   'cluster': 37},
#  {'text': 'doc river ll wait chris forsberg boston celtic captain paul pierce departed thursday',
#   'cluster': 67},
#  {'text': 'facebook privacy setting user', 'cluster': 95},
#  {'text': 'daily review murdoch ipad newspaper rupert murdoch ipad launch daily offer glitzy graphic',
#   'cluster': 54},
#  {'text': 'commercial video eminem lipton brisk super bowl commercial',
#   'cluster': 99},
#  {'text': 'updated rehab aim giffords life', 'cluster': 37},
#  {'text': 'breakingnews looter broke museum destroyed pharaonic mummy late friday nation top archaeologist reuters egypt',
#   'cluster': 10},
#  {'text': 'grant fishing smile set grant arizona game fish department ki',
#   'cluster': 60},
#  {'text': 'tech cnn hack facebook unlocks security facebook adding security feature',
#   'cluster': 95},
#  {'text': 'black swan amazing natalie portman deserves award doubt will',
#   'cluster': 101},
#  {'text': 'recipe chicken cutlet', 'cluster': 87},
#  {'text': 'favorited youtube video gm chevy super bowl commercial bumblebee',
#   'cluster': 99},
#  {'text': 'thousand protest jordan middle east', 'cluster': 38},
#  {'text': 'sundance today tobey maguire demi moore kate bosworth tobey maguire waitin',
#   'cluster': 96},
#  {'text': 'extraordinary stuff arrested beaten egypt police', 'cluster': 66},
#  {'text': 'florida top freshwater fishing destination', 'cluster': 60},
#  {'text': 'best fly fishing website', 'cluster': 60},
#  {'text': 'weight loss diet plan living healthy acai berry adi news acai berry promote weight loss imp',
#   'cluster': 55},
#  {'text': 'super bowl commercial', 'cluster': 99},
#  {'text': 'asia center graduate summer grant harvard university usa beasiswa scholarship',
#   'cluster': 97},
#  {'text': 'yemen girds day rage saleh vow step bloomberg', 'cluster': 79},
#  {'text': 'king speech lead academy award nomination including best picture',
#   'cluster': 88},
#  {'text': 'freemont tribune safety tip atm tip safety', 'cluster': 108},
#  {'text': 'man charged joanna yeates murder', 'cluster': 86},
#  {'text': 'internet news steve job medical problem affect apple stock latest internet news steve job',
#   'cluster': 106},
#  {'text': 'gop voter active social networking site political purpose washing artimpactnetpr',
#   'cluster': 45},
#  {'text': 'obama campaign playbook promote agenda social medium',
#   'cluster': 45},
#  {'text': 'don text drive makeachange', 'cluster': 104},
#  {'text': 'yemen arrest anti government activist yemen', 'cluster': 79},
#  {'text': 'king speech win top honor director guild award', 'cluster': 88},
#  {'text': 'mobile market grew smartphones android driver will drive marke',
#   'cluster': 81},
#  {'text': 'fishing report fishnotes caught bass gofishn', 'cluster': 60},
#  {'text': 'uk news lady take campaign childhood obesity army base',
#   'cluster': 65},
#  {'text': 'watch rite free movie online movie online', 'cluster': 14},
#  {'text': 'fly box folly north american fly fishing forum ongoing effort achieve system perfection',
#   'cluster': 60},
#  {'text': 'king speech dominates sag award win best picture osacrs sagawards thekingsspeech',
#   'cluster': 88},
#  {'text': 'arizona bid block citizenship illegal immigrant anchor baby tcot tlot',
#   'cluster': 82},
#  {'text': 'acai berry diet sexy acai berry scam warning acai berry diet',
#   'cluster': 55},
#  {'text': 'lmao didn feistyoldpeople chevy commercial superbowl',
#   'cluster': 99},
#  {'text': 'mouratoglou murray djokovic classic yahoo', 'cluster': 71},
#  {'text': 'endsmeat christina aguilera mess lyric national anthem super bowl',
#   'cluster': 75},
#  {'text': 'wilmington nc inshore winter fishing report', 'cluster': 60},
#  {'text': 'oscar nomination full list academy award nominee', 'cluster': 88},
#  {'text': 'indicator point great fall steelhead fishing', 'cluster': 60},
#  {'text': 'yemen protest intensify arrest journalist tawakkol karman',
#   'cluster': 79},
#  {'text': 'rash report social medium tool social unrest john rash tunisian mohamed bouazizi cou',
#   'cluster': 45},
#  {'text': 'commerce bos immigration reform', 'cluster': 82},
#  {'text': 'acai berry diet side effect lose weight fast acai berry diet side effe',
#   'cluster': 55},
#  {'text': 'great win packer christina land blunder', 'cluster': 75},
#  {'text': 'celebrity gossip fishing madison river montana', 'cluster': 60},
#  {'text': 'conan blast christina super bowl anthem blunder time',
#   'cluster': 75},
#  {'text': 'identity theft cost create problem business deal reaching fake provider showz',
#   'cluster': 108},
#  {'text': 'florida judge strike obamacare america', 'cluster': 22},
#  {'text': 'king speech rule obvious batch oscar bait news cnews canada',
#   'cluster': 88},
#  {'text': 'check price fly fishing lure ebay store info', 'cluster': 60},
#  {'text': 'debt consolidation help avoid bankruptcy debt consolidation involves single loan',
#   'cluster': 74},
#  {'text': 'acai berry acai berry juice weight loss', 'cluster': 55},
#  {'text': 'daddy prefers vw commercial messing mini darth superbowl dadstalking',
#   'cluster': 99},
#  {'text': 'slow news day chicago ll live bloggin mayoral debate cdt',
#   'cluster': 21},
#  {'text': 'super bowl commercial coca cola commercial coke', 'cluster': 99},
#  {'text': 'wished looked lucy hale kourtney kardashian pretty', 'cluster': 72},
#  {'text': 'reuters celebs hollywood actor honor king speech los angeles reuters oscar front runner king',
#   'cluster': 88},
#  {'text': 'best recipe caesar salad caesarsalad', 'cluster': 87},
#  {'text': 'school tackling cut teen concussion bull ring drill football',
#   'cluster': 84},
#  {'text': 'reason acai berry weight loss diet case half popula',
#   'cluster': 55},
#  {'text': 'court allows emanuel ballot chicago mayor nytimes tlot news illinois dems',
#   'cluster': 21},
#  {'text': 'trout steelhead fly fishing supply stretched canvas poster steelhead trout image',
#   'cluster': 60},
#  {'text': 'fatal blast reported moscow airport terminal russian authority monday reported fatal explosion',
#   'cluster': 36},
#  {'text': 'simple easy prepare vintage fried chicken recipe', 'cluster': 87},
#  {'text': 'huffingtonpost sundance film festival james franco three company installation',
#   'cluster': 96},
#  {'text': 'australia flooding cost enormous', 'cluster': 98},
#  {'text': 'win djokovic won australian open', 'cluster': 71},
#  {'text': 'cnn killed injured terror blast moscow airport terrorist suicide bomber blamed mosco',
#   'cluster': 36},
#  {'text': 'fishing bait bait trout fishing trout fishing type equipment dictate',
#   'cluster': 60},
#  {'text': 'actress farmiga sundance directing debut reuters reuters vera farmiga big breakout',
#   'cluster': 96},
#  {'text': 'dc medium opt tea party tea party caucus remains vigilant teaparty tcot tlot gop dem',
#   'cluster': 103},
#  {'text': 'youtube video eminem lipton brisk super bowl commercial',
#   'cluster': 99},
#  {'text': 'jordan protester gather country demanding prime minister step al jazeera',
#   'cluster': 38},
#  {'text': 'credit card debt consolidation gt credit card studentloans info conso',
#   'cluster': 74},
#  {'text': 'sow bug round north american fly fishing forum time march mountain',
#   'cluster': 60},
#  {'text': 'meat high quality mediapost beef brouhaha taco bell buzz suffering mediapost',
#   'cluster': 20},
#  {'text': 'clinton bugun misir hk nededi secretary clinton condemns attack demonstrator journalist egypt vide jan',
#   'cluster': 66},
#  {'text': 'weight loss diet plan south american acai berry currently american lose',
#   'cluster': 55},
#  {'text': 'acai berry weight loss diet plan healthy weight reduction',
#   'cluster': 55},
#  {'text': 'missouri court rule immigrant adoption right terminated illegally missouri supreme court tuesday ove',
#   'cluster': 82},
#  {'text': 'king speech usurps throne oscar leader ap', 'cluster': 88},
#  {'text': 'coming airport modesty change', 'cluster': 25},
#  {'text': 'super bowl national anthem singer christina aguilera fail video',
#   'cluster': 75},
#  {'text': 'chrysler telling story well check chrysler commercial imported detroit',
#   'cluster': 99},
#  {'text': 'top story illinois supreme court rahm emanuel ballot illinois supreme court issued ruling',
#   'cluster': 21},
#  {'text': 'weight loss diet acai berry weight loss diet plan diet diet food weight loss beauty sally beauty bea',
#   'cluster': 55},
#  {'text': 'entent complete list nomination annual academy award',
#   'cluster': 88},
#  {'text': 'hella funnny drt superbowl funniest doritos commercial',
#   'cluster': 99},
#  {'text': 'undergraduate scholarship international college hotel management australia beasiswa schola',
#   'cluster': 97},
#  {'text': 'hott cold sundance film festival lola blog', 'cluster': 96},
#  {'text': 'discus fish aquarium', 'cluster': 60},
#  {'text': 'netherlands recall iran ambassador dutch woman execution foreign policy outrage',
#   'cluster': 42},
#  {'text': 'video volkswagen invades super bowl darth vader starwars superbowl',
#   'cluster': 99},
#  {'text': 'best buy launch electronics buy program', 'cluster': 85},
#  {'text': 'workshop offer help student aid form regional workshop open help faf',
#   'cluster': 97},
#  {'text': 'drive text', 'cluster': 104},
#  {'text': 'heard acai berry diet acai berry heard diet purchasing',
#   'cluster': 55},
#  {'text': 'continuing cooking winning streak awesome lemon fennel pot roast chicken chicken boring',
#   'cluster': 87},
#  {'text': 'red fishing knot book book fishing harry', 'cluster': 60},
#  {'text': 'wikileaks pushed uk sanction iranian bank cable view britain settin jpost',
#   'cluster': 110},
#  {'text': 'king speech wint twee screen actor guild award', 'cluster': 88},
#  {'text': 'beck rating plummeted', 'cluster': 59},
#  {'text': 'aaron rodgers helmet saved concussion bear green bay packer qb aaron rodgers believ',
#   'cluster': 84},
#  {'text': 'don text drive', 'cluster': 104},
#  {'text': 'aguilera repeat national anthem', 'cluster': 75},
#  {'text': 'facebook privacy setting user', 'cluster': 95},
#  {'text': 'watching superbowl darth vader commercial awesome love dude',
#   'cluster': 99},
#  {'text': 'ncis stupidest fucking television', 'cluster': 77},
#  {'text': 'international scholarship bangor university uk beasiswa scholarship',
#   'cluster': 97},
#  {'text': 'fish eat complete fishing guide', 'cluster': 60},
#  {'text': 'live state massachusetts financial aid college', 'cluster': 97},
#  {'text': 'bbc yemeni rally president thousand yemeni demonstrating capital sanaa calling president ali abdullah',
#   'cluster': 79},
#  {'text': 'applying financial aid groundless myth', 'cluster': 97},
#  {'text': 'dutch government end official contact iran protest hanging dutch iranian woman al jazeera',
#   'cluster': 42},
#  {'text': 'reporting arrest journalist cairo', 'cluster': 66},
#  {'text': 'rnc money ronald reagan birthday', 'cluster': 100},
#  {'text': 'charlottesville city school offering student vegetarian option lunch',
#   'cluster': 102},
#  {'text': 'prettyman annual fish porn provider coming fly fishing film festival bring subject called',
#   'cluster': 60},
#  {'text': 'three journalist tf detained cairo jan mubarak egypt egipto fb',
#   'cluster': 66},
#  {'text': 'egypt ripple ally yemeni prez ali abdullah saleh power year won seek term',
#   'cluster': 79},
#  {'text': 'eastern sport outdoor harrisburg hunting fishing idea marcus schneck patrio',
#   'cluster': 60},
#  {'text': 'don care starbucks trenta cup bigger stomach', 'cluster': 62},
#  {'text': 'al jazeera report region yemen pres extend term protest call syria',
#   'cluster': 79},
#  {'text': 'revolt contagious anti government protest spread yemen tcot tlot jan sidibouzid',
#   'cluster': 79},
#  {'text': 'american fishing book guide value', 'cluster': 60},
#  {'text': 'king speech win big dgas award season tight race social network',
#   'cluster': 88},
#  {'text': 'vw black beetle commercial favorite super bowl ad night',
#   'cluster': 99},
#  {'text': 'canadian journalist detained harassed foreign journalist targeted cairo',
#   'cluster': 66},
#  {'text': 'sidney crosby concussion raise safety debate hockey spark discussion',
#   'cluster': 84},
#  {'text': 'omg oprah plege wouldn text drive didn seriously lol xd bbl',
#   'cluster': 104},
#  {'text': 'wlcentral yemen day rage february egypt jan yemen feb',
#   'cluster': 79},
#  {'text': 'law suit taco bell beef filler find taco bell chihuahua',
#   'cluster': 20},
#  {'text': 'chipotle caught immigration crosshairs yahoo news knew genuine mexican working',
#   'cluster': 80},
#  {'text': 'love kardashian doll fave doll khloe gt', 'cluster': 72},
#  {'text': 'elizabeth olsen sundance film festival debut sister footstep theatrical',
#   'cluster': 96},
#  {'text': 'screen actor guild award list winner sag king speech reign supreme edie falco',
#   'cluster': 88},
#  {'text': 'facebook finally offer http change setting', 'cluster': 95},
#  {'text': 'competitive fishing tactic fly everyday fisherman thinking man',
#   'cluster': 60},
#  {'text': 'creamy recipe fettuccine alfredo chicken recipe', 'cluster': 87},
#  {'text': 'ice fishing bro brohsdahl jason mitchell byron eckhardt special ice fishing schtick',
#   'cluster': 60},
#  {'text': 'flyfishing big earth publishing flyfishing barry reynolds bass walleye buy john',
#   'cluster': 60},
#  {'text': 'interview venezuela sweetheart champion chavez venezuelan president hugo chavez speaks meeting',
#   'cluster': 56},
#  {'text': 'court emanuel eligible chicago mayor ny time pa habit sur place assez longtemps',
#   'cluster': 21},
#  {'text': 'jay carney white house press secretary richard adam guardian',
#   'cluster': 44},
#  {'text': 'king speech top screen actor guild award winner mtv movie music',
#   'cluster': 88},
#  {'text': 'insurance news federal judge reject health reform law district court judge roger vinson agreed',
#   'cluster': 22},
#  {'text': 'attorney general office identity theft prevention tip west virginia attorney general darrell mcgraw',
#   'cluster': 108},
#  {'text': 'duraflame log beef taco bell', 'cluster': 20},
#  {'text': 'superbowl volkswagen commercial force', 'cluster': 99},
#  {'text': 'hilarious super bowl commercial', 'cluster': 99},
#  {'text': 'web daily stunning slow day launch daily ipad newspaper ipad',
#   'cluster': 54},
#  {'text': 'sundance familiar territory elizabeth bank omg', 'cluster': 96},
#  {'text': 'hellothere king speech win sag award king speech win best actor trophy sunday bythere',
#   'cluster': 88},
#  {'text': 'reporter attacked attack journalist send message', 'cluster': 66},
#  {'text': 'case haven brilliant motorola xoom ad super bowl', 'cluster': 99},
#  {'text': 'justin bieber address danger texting driving extreme makeover music celebrity justin bieber',
#   'cluster': 104},
#  {'text': 'fda approved injectable drug called makena reduce risk preterm delivery week',
#   'cluster': 58},
#  {'text': 'yemeni president ruled decade ll seek extend term pas power son reuters',
#   'cluster': 79},
#  {'text': 'brytec fly fishing box brytec fishing', 'cluster': 60},
#  {'text': 'aquarium fish basic plant container garden pl', 'cluster': 60},
#  {'text': 'school tackling cut teen concussion', 'cluster': 84},
#  {'text': 'dont text drive', 'cluster': 104},
#  {'text': 'thousand jordan protest demand pm step day protest opposition supporter stre',
#   'cluster': 38},
#  {'text': 'novak djokovic win australian open well deserved played amazing couldn help feel andy murray',
#   'cluster': 71},
#  {'text': 'bad best commercial movie trailer random urge buy doritos bud light superbowl',
#   'cluster': 99},
#  {'text': 'type identity theft dark dragon grownup identity theft',
#   'cluster': 108},
#  {'text': 'guided fly fishing muskegon river trout', 'cluster': 60},
#  {'text': 'love khloe alexandra kardashian biggest fan kuwait will meet',
#   'cluster': 72},
#  {'text': 'king speech rule obvious batch oscar bait ap', 'cluster': 88},
#  {'text': 'recap steve job will good time apple', 'cluster': 106},
#  {'text': 'gt annual academy award nomination announced man ve best picture noms',
#   'cluster': 88},
#  {'text': 'today stock market dow jones industrial average dji nasdaq',
#   'cluster': 92},
#  {'text': 'doctor giffords face rocky road recovery day week rep gabrielle giffords recovery',
#   'cluster': 37},
#  {'text': 'france fox piven defies death threat taunt anchorman glenn beck mental',
#   'cluster': 40},
#  {'text': 'reuters top news yemen president won extend term pas son',
#   'cluster': 79},
#  {'text': 'oscar nominated gasland director josh fox gas drilling barnett shale dallas observer blog',
#   'cluster': 109},
#  {'text': 'full video super bowl national anthem singer christina aguilera fail imalive',
#   'cluster': 75},
#  {'text': 'political power social medium foreign affair', 'cluster': 45},
#  {'text': 'identity theft steal social security number theft', 'cluster': 108},
#  {'text': 'complete book fly fishing', 'cluster': 60},
#  {'text': 'college best financial aid arizona state university',
#   'cluster': 97},
#  {'text': 'spreading thousand protest jordan demand pm step aljazeera net',
#   'cluster': 38},
#  {'text': 'manchester austerity cut hit frontline service leisure centre library swimming pool public toile',
#   'cluster': 51},
#  {'text': 'thing social medium revolution', 'cluster': 45},
#  {'text': 'best buy launch electronics buy program ap', 'cluster': 85},
#  {'text': 'social network king speech aim oscar ap ap academy award voter poised set showd',
#   'cluster': 88},
#  {'text': 'ticker thousand yemeni call president quit', 'cluster': 79},
#  {'text': 'australian open final novak djokovic andy murray live blog bleacher report contributor scott',
#   'cluster': 71},
#  {'text': 'yemen republican guard dispatched roaming street sana reliable source',
#   'cluster': 79},
#  {'text': 'cbc ticker southeast australia brace flood australia deadly flood crisis forced people',
#   'cluster': 98},
#  {'text': 'fda approves pharma preterm birth drug embattled drugmaker pharmaceutical reported health reg',
#   'cluster': 58},
#  {'text': 'acai berry weight loss confusing helen arsenault january talk mogul op',
#   'cluster': 55},
#  {'text': 'update fly fishing tip beginner ultimate guide learn fly fish pro',
#   'cluster': 60},
#  {'text': 'ufo paranormal terrorist bombing moscow airport', 'cluster': 36},
#  {'text': 'hawaii won release obama birth info', 'cluster': 41},
#  {'text': 'horse racing oc tavern bar state offer track horse betting',
#   'cluster': 94},
#  {'text': 'starbucks size trente hold entire bottle wine enjoy',
#   'cluster': 62},
#  {'text': 'super bowl recipe todd dirt dirt man shared recipe patch ve ta',
#   'cluster': 87},
#  {'text': 'spicy food popular child quick thai style chicken soup will hit',
#   'cluster': 87},
#  {'text': 'crystal clear kim kardashian single fucking idiot', 'cluster': 72},
#  {'text': 'drug rehab work charlie sheen reportedly receiving help clearest benefit pat',
#   'cluster': 68},
#  {'text': 'social network king speech aim oscar ap ap academy award voter poised set',
#   'cluster': 88},
#  {'text': 'real acai berry supplement deal rapid fast weight loss well ordered acai berry blast',
#   'cluster': 55},
#  {'text': 'watching extreme makeover don text drive', 'cluster': 104},
#  {'text': 'gotta luv video jesse ventura strike lawsuit tsa', 'cluster': 25},
#  {'text': 'acai berry social bookmarking net acai berry latest weight loss buy acai berry best colon cleanse',
#   'cluster': 55},
#  {'text': 'worst best super bowl commercial video', 'cluster': 99},
#  {'text': 'st andrew st michael school hold second annual bullying awareness conference',
#   'cluster': 90},
#  {'text': 'supreme court temporarily halt georgia execution', 'cluster': 89},
#  {'text': 'acai berry powder ehow acai berry powder acai berry extraordinarily',
#   'cluster': 55},
#  {'text': 'chicken vegetable herb brown rice', 'cluster': 87},
#  {'text': 'egypt military secures famed antiquity museum', 'cluster': 10},
#  {'text': 'completely freaky sense sony xperia play commercial kind awesome creepy thumb superbowl',
#   'cluster': 99},
#  {'text': 'love coke commercial dragon superbowl', 'cluster': 99},
#  {'text': 'al jazeera thousand egyptian youth form human shield protect egyptian museum museum egypt jan',
#   'cluster': 10},
#  {'text': 'tceltics davis leaf game sun sore hamstring boston celtic nbanewsfeed',
#   'cluster': 67},
#  {'text': 'street yemen day rage sanaa reuters yemeni', 'cluster': 79},
#  {'text': 'rahm emanuel ballot chicago alternet', 'cluster': 21},
#  {'text': 'judge rule health care law foxnews', 'cluster': 22},
#  {'text': 'fishing striped bass ll fight hard fish pull force lake norman st',
#   'cluster': 60},
#  {'text': 'charlie rating soar big bonus short rehab', 'cluster': 68},
#  {'text': 'cash college workshop tomorrow find location', 'cluster': 97},
#  {'text': 'audi super bowl commercial online video audi', 'cluster': 99},
#  {'text': 'fishing report jan illinois winter steelhead fishing good driftboaters cop',
#   'cluster': 60},
#  {'text': 'patrick asks obama intervene fishing regulation dispute',
#   'cluster': 60},
#  {'text': 'expert differ sanction debate', 'cluster': 110},
#  {'text': 'chipotle face ice inspection state reuters', 'cluster': 80},
#  {'text': 'skinny burn fat', 'cluster': 55},
#  {'text': 'walmart embrace lady nutrition campaign', 'cluster': 65},
#  {'text': 'fishing rapala original floater fishing lure original floating rapala fished fishingkahuna',
#   'cluster': 60},
#  {'text': 'super bowl prediction volkswagen commercial force beat audi goodnight commercial seo',
#   'cluster': 99},
#  {'text': 'autism awareness month education key bully', 'cluster': 90},
#  {'text': 'rioter destroy mummy egyptian museum cairo filed art culture history learning afric',
#   'cluster': 10},
#  {'text': 'bottega veneta rtw spring beautiful fashion art gt', 'cluster': 46},
#  {'text': 'mainenance fishing rod preserving rod read', 'cluster': 60},
#  {'text': 'lt gt acai berry lt gt weight loss side effect improvement',
#   'cluster': 55},
#  {'text': 'blizzard break chicago snow record inch expected', 'cluster': 57},
#  {'text': 'suicide bomber blamed moscow airport attack killed russian state tv report',
#   'cluster': 36},
#  {'text': 'save text save life don text driving text life imagine dream inspire',
#   'cluster': 104},
#  {'text': 'ford paid shit load commercial air time superbowl', 'cluster': 99},
#  {'text': 'smart money future mixed ahead data earnings market update stock future mi investing money',
#   'cluster': 92},
#  {'text': 'starbucks terrifying trenta cup hold entire bottle wine',
#   'cluster': 62},
#  {'text': 'msn today joanna yeates suspect court', 'cluster': 86},
#  {'text': 'illinois state appeal court declared rahm emanuel ineligible mayor chicago born kenya',
#   'cluster': 21},
#  {'text': 'exactly acai berry diet pill wrk yahoo answer acai berry diet pill',
#   'cluster': 55},
#  {'text': 'buck belief nba concussion protocol three year ago ucla luc richard mbah moute sust',
#   'cluster': 84},
#  {'text': 'tip help reduce energy bill control electricity save money power bill',
#   'cluster': 27},
#  {'text': 'breaking news fluid buildup rep giffords brain will delay start full fledged rehabilitation hou',
#   'cluster': 37},
#  {'text': 'toledo bend report chicken coop providing hot crappie action love bass fishing bu',
#   'cluster': 60},
#  {'text': 'rid bedbug', 'cluster': 52},
#  {'text': 'favorite superbowl motorola xoom tablet swipe apple tonight',
#   'cluster': 99},
#  {'text': 'awesome bold superbowl commercial seriously going consider xoom tablet ipad',
#   'cluster': 99},
#  {'text': 'identity theft cost infographic', 'cluster': 108},
#  {'text': 'tip fly fishing brook trout stream manual angler ten tip fly',
#   'cluster': 60},
#  {'text': 'sixth annual avnet tech game offer scholarship networking opportunity winning student will',
#   'cluster': 97},
#  {'text': 'dorritos pepsi commercial tyrant superbowl commercial',
#   'cluster': 99},
#  {'text': 'rite movie review fan movie deal battle good', 'cluster': 14},
#  {'text': 'gang hunt journalist right worker egypt nytimes jatkhs',
#   'cluster': 66},
#  {'text': 'kardashians episode good', 'cluster': 72},
#  {'text': 'social medium blast christina aguilera national anthem super bowl flub day social medium',
#   'cluster': 75},
#  {'text': 'sinfully spicy easy easy eat reshmi chicken kebab roll indianfood recipe indianfastfood',
#   'cluster': 87},
#  {'text': 'identity theft cost infographic online fraud crime rise mo',
#   'cluster': 108},
#  {'text': 'commercial motorola xoom suck people apple tool sb superbowl',
#   'cluster': 99},
#  {'text': 'white stripe breaking performance record winnipeg free press',
#   'cluster': 17},
#  {'text': 'mercedes benz class coupe sl amg roadster revealed superbowl commercial tmr',
#   'cluster': 99},
#  {'text': 'murray congratulation djokovic winning men australianopen championship nice work going bed',
#   'cluster': 71},
#  {'text': 'portman firth speech win sag award los angeles jan upi star king speech ho',
#   'cluster': 88},
#  {'text': 'police open fire yemen protester sanaa yemen ap witness police opened fire break',
#   'cluster': 79},
#  {'text': 'variety freshwater aquarium fish', 'cluster': 60},
#  {'text': 'save poptarts tmr chicago foot snow hour forecaster',
#   'cluster': 57},
#  {'text': 'rnc best shot knocking debt time race leading pack',
#   'cluster': 100},
#  {'text': 'pound test bass fishing rod yahoo answer', 'cluster': 60},
#  {'text': 'watched solid acting anthony hopkins sr beauty alice braga rite view',
#   'cluster': 14},
#  {'text': 'acai berry weight loss diet plan healthy weight reduction number diet plan',
#   'cluster': 55},
#  {'text': 'master phd scholarship university manitoba canada beasiswa scholarship',
#   'cluster': 97},
#  {'text': 'best worm bait fishing thom conroy helium', 'cluster': 60},
#  {'text': 'acai berry work lose weight lose weight heard acai berry pe',
#   'cluster': 55},
#  {'text': 'journalist targeted pro mubarak force egypt video', 'cluster': 66},
#  {'text': 'bbc news king speech lead oscar field', 'cluster': 88},
#  {'text': 'student juvenile arthritis apply college scholarship staff report arthritis foundation',
#   'cluster': 97},
#  {'text': 'love ncis arc outcome funeral', 'cluster': 77},
#  {'text': 'leon payn bottega veneta coming', 'cluster': 46},
#  {'text': 'egypt protest gauntlet officer beating stick', 'cluster': 66},
#  {'text': 'yemen president quit february updated', 'cluster': 79},
#  {'text': 'suicide bomber kill moscow airport explosion ripped interna lukewilliamss',
#   'cluster': 36},
#  {'text': 'starbucks trenta cup hold entire bottle wine random starbucks trenta college',
#   'cluster': 62},
#  {'text': 'vincent tabak man accused jo yeates murder deeply saddened death telegraph',
#   'cluster': 86},
#  {'text': 'florida judge declares entire healthcare law void month half ago virginia judge key pr',
#   'cluster': 22},
#  {'text': 'motorola xoom super bowl commercial tip hat apple spot video',
#   'cluster': 99},
#  {'text': 'fly fishing magazine guide', 'cluster': 60},
#  {'text': 'cost financial aid chicago school professional psychology',
#   'cluster': 97},
#  {'text': 'eminem brisk super bowl commercial', 'cluster': 99},
#  {'text': 'american journalist bloodied detained egyptian force dozen foreign journalist egypt attac',
#   'cluster': 66},
#  {'text': 'gallery celebrity sighting sundance film festival', 'cluster': 96},
#  {'text': 'whycollegenow present college scholarship fantastic post college scholar',
#   'cluster': 97},
#  {'text': 'll sporting mine will mac wednesday february anti bullying day',
#   'cluster': 90},
#  {'text': 'identity theft cost infographic long ago identity theft online',
#   'cluster': 108},
#  {'text': 'favorite thing chicken breast', 'cluster': 87},
#  {'text': 'glenn beck rating year ago fb', 'cluster': 59},
#  {'text': 'judge strike healthcare reform law', 'cluster': 22},
#  {'text': 'tsa body scanner spot bomb dong tsa', 'cluster': 25},
#  {'text': 'boston celtic jermaine neal arthroscopic knee surgery recovery period week espn nba',
#   'cluster': 67},
#  {'text': 'video terror texting toronto gta news toronto sun', 'cluster': 104},
#  {'text': 'weight loss diet plan living healthy acai berry adi news acai berry promote weight loss imp',
#   'cluster': 55},
#  {'text': 'fishing ski report detroit free press ice fishing continues heavy snow will travel',
#   'cluster': 60},
#  {'text': 'nut war medium continues al jazeera journalist arrested cairo camera equipment seized egypt jan aljazeera',
#   'cluster': 66},
#  {'text': 'best buy future proof tech purchase buy program cost istockanalyst press release',
#   'cluster': 85},
#  {'text': 'james franco platinum blonde hilarious jac', 'cluster': 96},
#  {'text': 'obsession gt ncis', 'cluster': 77},
#  {'text': 'egyptian military rounding journalist egypt pm issue apology star egypt live blog jan',
#   'cluster': 66},
#  {'text': 'full list nominee official oscar website', 'cluster': 88},
#  {'text': 'phife dawg atcq speaking sundance film festival video',
#   'cluster': 96},
#  {'text': 'caught lb pike flick fishing flickfishing', 'cluster': 60},
#  {'text': 'right group claim chavez judiciary foe', 'cluster': 56},
#  {'text': 'vote favorite superbowl commercial poll don love', 'cluster': 99},
#  {'text': 'march yemen president day rage', 'cluster': 79},
#  {'text': 'car commercial boring volkswagon enjoyed superbowl spot',
#   'cluster': 99},
#  {'text': 'option credit card debt consolidation loan', 'cluster': 74},
#  {'text': 'didn doritos commercial boring superbowl', 'cluster': 99},
#  {'text': 'pcworld android tablet smartphone boost samsung', 'cluster': 81},
#  {'text': 'film rite based training real priest film faith catholic exorcist',
#   'cluster': 14},
#  {'text': 'consumerist tsa testing revealing full body scanner software',
#   'cluster': 25},
#  {'text': 'star head sundance', 'cluster': 96},
#  {'text': 'hillary clinton egypt state hillary clinton treatment journalist coveri',
#   'cluster': 66},
#  {'text': 'news day starbucks trenta cup hold entire bottle wine',
#   'cluster': 62},
#  {'text': 'live tweet taco bell claim meat beef wasn typo', 'cluster': 20},
#  {'text': 'giffords condition upgraded good', 'cluster': 37},
#  {'text': 'social medium tool protest middle east police worst',
#   'cluster': 45},
#  {'text': 'pack vw superbowl darth vader commercial easily best well vw',
#   'cluster': 99},
#  {'text': 'best buy target launch buy electronics offer currently rachel blog travel industry news',
#   'cluster': 85},
#  {'text': 'motorward kia optimum epic ride super bowl commercial',
#   'cluster': 99},
#  {'text': 'celebrity sighting sundance film festival', 'cluster': 96},
#  {'text': 'protest erupt yemen', 'cluster': 79},
#  {'text': 'indian navy arrest pirate drama high sea major anti piracy operation',
#   'cluster': 107},
#  {'text': 'yemeni president ali abdullah saleh will seek extend presidency appoint son role current',
#   'cluster': 79},
#  {'text': 'pesto presto chicken pesto presto chicken feel good favorite cozy meal famil',
#   'cluster': 87},
#  {'text': 'russia stuxnet caused chernobyl david brunnstrom reuters david brunnstrom reuters rus',
#   'cluster': 83},
#  {'text': 'political power social medium foreign affair', 'cluster': 45},
# ...
#  {'text': 'mba scholarship nottingham university business school uk beasiswa scholarship',
#   'cluster': 97},
#  {'text': 'dtn news judge strike part health care law federal judge ruled presiden',
#   'cluster': 22},
#  {'text': 'super bowl xlv christina aguilera repeat national anthem espn',
#   'cluster': 75},
#  {'text': 'acai berry effective weight loss health benefit article will explain aca',
#   'cluster': 55},
#  {'text': 'news sen paul tea party hold power hill predicted tea party movement',
#   'cluster': 103},
#  {'text': 'super bowl recipe buffalo chicken pizza', 'cluster': 87},
#  {'text': 'breaking al jazeera journalist arrested cairo egypt crowd grows tahrir',
#   'cluster': 66},
#  {'text': 'chevy run deep chevrolet commercial superbowl ad check imabuzzagent',
#   'cluster': 99},
#  {'text': 'christina aguilera fluff national anthem', 'cluster': 75},
#  {'text': 'npr fda approves drug prevent preterm birth', 'cluster': 58},
#  {'text': 'andreawoo talked chrysler superbowl commercial', 'cluster': 99},
#  {'text': 'facebook instant personalization privacy setting sharing innermost secret',
#   'cluster': 95},
#  {'text': 'oscar nomination draw attention pa gas drilling gasland fracking',
#   'cluster': 109},
#  {'text': 'identity theft cost infographic online fraud crime rise mo',
#   'cluster': 108},
#  {'text': 'federal judge florida strike obama health care plan south florida',
#   'cluster': 22},
#  {'text': 'stuxnet concern iranian health ministry york time published report week describing stuxnet',
#   'cluster': 83},
#  {'text': 'eliza dushku drop sundance adorable ll admit thing eliza dushku',
#   'cluster': 96},
#  {'text': 'blog post beefy', 'cluster': 20},
#  {'text': 'volkswagen commercial force superbowl toocute', 'cluster': 99},
#  {'text': 'lizzie olsen storm sundance film festival kevin dolak buzz worthy film premiering week',
#   'cluster': 96},
#  {'text': 'exsteme makeover grabbing heart don text drive', 'cluster': 104},
#  {'text': 'king speech land nomination award season favorite social network trail true grit',
#   'cluster': 88},
#  {'text': 'will facebook privacy seriously site import facebook profile permission cnn',
#   'cluster': 95},
#  {'text': 'china praise hu trip fruitful yahoo news', 'cluster': 61},
#  {'text': 'unique college scholarship student', 'cluster': 97},
#  {'text': 'watch australian open men tennis final live online will history andy murray',
#   'cluster': 71},
#  {'text': 'superbowl commercial kale fitblog', 'cluster': 99},
#  {'text': 'charlie sheen leaf hospital medical emergency', 'cluster': 68},
#  {'text': 'french journalist arrested cairo', 'cluster': 66},
#  {'text': 'super bowl xlv christina aguilera repeat national anthem',
#   'cluster': 75},
#  {'text': 'journalist attacked detained egypt big hollywood', 'cluster': 66},
#  {'text': 'obamacare struck stage set showdown federal judge monday struck',
#   'cluster': 22},
#  {'text': 'fishing rule federal panel table kevin wadlow annual harvest popular recreational fish',
#   'cluster': 60},
#  {'text': 'best super bowl commercial commercial super bowl cream advertisi',
#   'cluster': 99},
#  {'text': 'sedative free whale fishing', 'cluster': 60},
#  {'text': 'yemen protest february day rage video news egypt jan mubarak syria libya jordan ugc',
#   'cluster': 79},
#  {'text': 'list journalist threatened attacked detained reporting egypt',
#   'cluster': 66},
#  {'text': 'egyptian army start rounding journalist jpost', 'cluster': 66},
#  {'text': 'twitter facebook blocked egypt news jan politics sm jan',
#   'cluster': 45},
#  {'text': 'airhead christina aguilera screw national anthem super bowl xlv tcot tlot',
#   'cluster': 75},
#  {'text': 'missouri court rule immigrant adoption right terminated illegally missouri supreme court tuesday overtu',
#   'cluster': 82},
#  {'text': 'photo star sundance hollywood contingent set shop mid',
#   'cluster': 96},
#  {'text': 'taco bell sued selling fake meat damn wonder fake lmao eating taco bell month ago haha',
#   'cluster': 20},
#  {'text': 'jmg court rule rahm emanuel ineligible mayor chicago opponent white house',
#   'cluster': 21},
#  {'text': 'toyota renews scholarship program donation american indian college fund denver jan prnewswi',
#   'cluster': 97},
#  {'text': 'cnn anti government protest yemen hundred anti government protester gathered news',
#   'cluster': 79},
#  {'text': 'quick avgolemono orzo chicken soup recipe', 'cluster': 87},
#  {'text': 'favorite superbowl commercial vw', 'cluster': 99},
#  {'text': 'andy murray australian open final will face djokovic atptennis yeg',
#   'cluster': 71},
#  {'text': 'academy award nominee', 'cluster': 88},
#  {'text': 'south korea target pirate incorporation anti piracy operation gulf aden op',
#   'cluster': 107},
#  {'text': 'social network king speech aim oscar', 'cluster': 88},
#  {'text': 'swanson vitamin review weight review acai berry buy calorie control weight swanson vitam',
#   'cluster': 55},
#  {'text': 'novak australian open champion', 'cluster': 71},
#  {'text': 'sending prayer marquis daniel boston celtic pray going okxo',
#   'cluster': 67},
#  {'text': 'acai berry eating regimen review lose lb rapid zwak org info acai berry benefit yo',
#   'cluster': 55},
#  {'text': 'crappie fishing wild fish recipe fishing tip minnesota fishing news wi',
#   'cluster': 60},
#  {'text': 'chevy volt commercial prolly best simple tell great story nicely brandbowl superbowl',
#   'cluster': 99},
#  {'text': 'don text drive', 'cluster': 104},
#  {'text': 'storm sign global warming mama believing', 'cluster': 29},
#  {'text': 'thousand protest jordan reform', 'cluster': 38},
#  {'text': 'amazing guardian journalist record audio arrest transport egypt police van jan',
#   'cluster': 66},
#  {'text': 'fed crack bedbug', 'cluster': 52},
#  {'text': 'protest sanaa yemen feb', 'cluster': 79},
#  {'text': 'nobel peace prize wikileaks', 'cluster': 12},
#  {'text': 'mbah moute nba concussion protocol usa today share friend sport basketball nba',
#   'cluster': 84},
#  {'text': 'popular fly fishing smallmouth bass auction', 'cluster': 60},
#  {'text': 'vincent tabak man accused jo yeates murder deeply saddened death',
#   'cluster': 86},
#  {'text': 'queensland flood blog arrived brisbane january surprised green',
#   'cluster': 98},
#  {'text': 'holy ball bloody omg novak djokovic australian open',
#   'cluster': 71},
#  {'text': 'fda ok viibryd treat depression fda approved drug called viibryd treat adult major depressiv',
#   'cluster': 58},
#  {'text': 'watch chrysler superbowl commercial youtube ad blitz channel',
#   'cluster': 99},
#  {'text': 'parent student educator tip preventing bullying ten district school organized event',
#   'cluster': 90},
#  {'text': 'rp cooking update italian recipe food cooking recipe',
#   'cluster': 87},
#  {'text': 'national hockey league concussion rise sidney crosby marc ap sport staff associated pressp',
#   'cluster': 84},
#  {'text': 'announcement lyon township high school host free college financial planning seminar feb patch',
#   'cluster': 97},
#  {'text': 'southeast australia set week flood', 'cluster': 98},
#  {'text': 'trout fishing tip learn wedding preparation trout fishing tip help catch bigger',
#   'cluster': 60},
#  {'text': 'lady focus military family childhood nutrition overstatement chi',
#   'cluster': 65},
#  {'text': 'greg biffle justin bieber address danger texting driving extreme makeover mtv',
#   'cluster': 104},
#  {'text': 'debt settlement program ftc law debt settlement better article learn',
#   'cluster': 74},
#  {'text': 'haha christina aguilera spelled bad sing fucked national anthem super bowl lol',
#   'cluster': 75},
#  {'text': 'journalist egypt brutally silenced equipment confiscated freedom press',
#   'cluster': 66},
#  {'text': 'waiting kktn tonight love kardashians', 'cluster': 72},
#  {'text': 'chipotle mexican grill received immigration custom enforcement notice inspection restaurant',
#   'cluster': 80},
#  {'text': 'minute court ruling allows rahm emanuel atlantic wire',
#   'cluster': 21},
#  {'text': 'latest news jesse ventura force tsa submission jennifer abel thing pr guardian usa',
#   'cluster': 25},
#  {'text': 'list academy award nomination chicago sun time', 'cluster': 88},
#  {'text': 'justin bieber jon stewart body snatching victim video',
#   'cluster': 63},
#  {'text': 'christina aguilera flub national anthem singing er rampart watched gallant',
#   'cluster': 75},
#  {'text': 'engel today egyptian unrest continues journalist targeted egypt jan',
#   'cluster': 66},
#  {'text': 'gear salmon fishing', 'cluster': 60},
#  {'text': 'lose weight world effective nutrition acai weight loss acai berry weight loss',
#   'cluster': 55},
#  {'text': 'natalie portman colin firth king speech winner sag melissa teo christian bale',
#   'cluster': 88},
#  {'text': 'save energy cash quick easy tip article will help save ton money saving en',
#   'cluster': 27},
#  {'text': 'bioportfolio news fda approves drug reduce preterm delivery risk pharmaceutical busi bioportfolio news',
#   'cluster': 58},
#  {'text': 'climate change update bizarre weather destroyed crop legendary fund manager jeremy grantham weig',
#   'cluster': 29},
#  {'text': 'bully sense anxiety relaxation technique', 'cluster': 90},
#  {'text': 'alert best buy announces buy program electronics news alert',
#   'cluster': 85},
#  {'text': 'thing social medium revolution activist twitter', 'cluster': 45},
#  {'text': 'king speech dominates oscar nomination', 'cluster': 88},
#  {'text': 'full list oscar nominee', 'cluster': 88},
#  {'text': 'favorite superbowl commercial doritos snicker darth vader volkswagen commercial pretty funny',
#   'cluster': 99},
#  {'text': 'changing facebook place privacy setting opportunity business location based mobile marketin',
#   'cluster': 95},
#  {'text': 'egyptian army start rounding journalist egyptian military rounded journalist thursday',
#   'cluster': 66},
#  {'text': 'cuomo expose dirty budget trick cut announced today',
#   'cluster': 19},
#  {'text': 'black swan trippy natalie portman good performance',
#   'cluster': 101},
#  {'text': 'watch christina agulilera botch national anthem super bowl michael mccarthy usa today heard',
#   'cluster': 75},
#  {'text': 'cal grant financial aid application california student launched student maximize aid option app',
#   'cluster': 97},
#  {'text': 'future iran nuclear talk ahmadinejad afp afp iran president mahmoud ahmadinejad',
#   'cluster': 73},
#  {'text': 'oscar nomination box office help king speech soar tuesday dilemma box',
#   'cluster': 88},
#  {'text': 'chrysler commercial eminem best bad car terrible superbowl',
#   'cluster': 99},
#  {'text': 'carp secret homemade fish bait recipe catch bigger carp pole bending time tested fish bait',
#   'cluster': 60},
#  {'text': 'news video white stripe call quits read breakup rip bummer',
#   'cluster': 17},
#  {'text': 'couldn place tsa unveils modest body scanner abc news',
#   'cluster': 25},
#  {'text': 'today president alisaleh yemen vowed election support peaceful transition power feb',
#   'cluster': 79},
#  {'text': 'eminem super bowl commercial damn chrysler commercial imported detroit',
#   'cluster': 99},
#  {'text': 'egypt turn internet long broadcast violence strongarms journalist leave',
#   'cluster': 66},
#  {'text': 'olbermann land current grow york adage outspoken tv host keith olbermann fresh',
#   'cluster': 30},
#  {'text': 'acai berry scam free trial weight loss genius scam associated acai berry supposed',
#   'cluster': 55},
#  {'text': 'lmao check funny commercial doritos pepsi max', 'cluster': 99},
#  {'text': 'identity theft cost infographic', 'cluster': 108},
#  {'text': 'yemen day rage draw ten thousand', 'cluster': 79},
#  {'text': 'legal news study red light camera save life nwindiana',
#   'cluster': 64},
#  {'text': 'king speech top directing prize', 'cluster': 88},
#  {'text': 'tunisia egypt yemen', 'cluster': 79},
#  {'text': 'recognizes reduced state spending key solving ny fiscal crisis',
#   'cluster': 19},
#  {'text': 'usa national anthem hard song sing', 'cluster': 75},
#  {'text': 'chevy volt super bowl commercial discovery sb sbxlv',
#   'cluster': 99},
#  {'text': 'white stripe officially broke thought record devastated',
#   'cluster': 17},
#  {'text': 'catalan tv team foreign journalist detained military police cairo',
#   'cluster': 66},
#  {'text': 'pirate battle free norwegian ship', 'cluster': 107},
#  {'text': 'briton killed moscow blast uk foreign office report british citizen',
#   'cluster': 36},
#  {'text': 'glenn beck fran piven michael tomasky comment free americafirst',
#   'cluster': 40},
#  {'text': 'facebook privacy setting user facebook privacy setting extremely detailed',
#   'cluster': 95},
#  {'text': 'discus fish aquarium', 'cluster': 60},
#  {'text': 'superbowl pepsi commercial best', 'cluster': 99},
#  {'text': 'king speech lead oscar race nomination nominee annual academy award',
#   'cluster': 88},
#  {'text': 'navy destroys pirate mother ship arrest pirate indian navy coast guard joint operatio',
#   'cluster': 107},
#  {'text': 'latest dallas super bowl fiasco seat north texas rough week super bowl host',
#   'cluster': 24},
#  {'text': 'charlie sheen abuse', 'cluster': 68},
#  {'text': 'industry boo oscar nod gasland', 'cluster': 109},
#  {'text': 'american fishing wire duo lock snap size lb sizescorrosion resistant black finish',
#   'cluster': 60},
#  {'text': 'footballer destroying kid brain game', 'cluster': 84},
#  {'text': 'journalist attacked detained egypt rtdna condemns assault',
#   'cluster': 66},
#  {'text': 'florida immigration law focused employer hasn enforced politics ap miamiherald',
#   'cluster': 82},
#  {'text': 'president yemen ali abdullah saleh will seek extend presidential term pas power son jan yemen feb',
#   'cluster': 79},
#  {'text': 'lfc king speech nominated oscar bad considering game',
#   'cluster': 88},
#  {'text': 'ih industry news chipotle scrutiny ice', 'cluster': 80},
#  {'text': 'justin bieber extreme makeover fan kid teen warning text drive inspired touched',
#   'cluster': 104},
#  {'text': 'robert redford open anniversary sundance film festival protest planned',
#   'cluster': 96},
#  {'text': 'judge entire hc law piper', 'cluster': 22},
#  {'text': 'saltwater fish tank harmful human help', 'cluster': 60},
#  {'text': 'packer win super bowl christina aguilera national anthem wrong news sky xy',
#   'cluster': 75},
#  {'text': 'pak thousand yemeni demand govt change thousand yemeni street capital sanaa inspir',
#   'cluster': 79},
#  {'text': 'facebook privacy setting nicholas jackson facebook privacy option',
#   'cluster': 95},
#  {'text': 'don text drive example cell phone driving backseat',
#   'cluster': 104},
#  {'text': 'novak djokovic champion australian open', 'cluster': 71},
#  {'text': 'checkout fishing fishinggear deal save', 'cluster': 60},
#  {'text': 'uk news neighbour remanded jo yeates murder', 'cluster': 86},
#  {'text': 'tracyjones college student file fafsa fafsa government eligibility',
#   'cluster': 97},
#  {'text': 'hahaha doritoes commercial best superbowl', 'cluster': 99},
#  {'text': 'neighbour remanded jo yeates murder', 'cluster': 86},
#  {'text': 'watching keeping kardashins lol', 'cluster': 72},
#  {'text': 'hashtags tv ad superbowl audi launch commercial twitter hashtag',
#   'cluster': 99},
#  {'text': 'gas industry doesn gasland oscar nod figure fracking marcellus',
#   'cluster': 109},
#  {'text': 'illinois supreme court rahm emanuel ballot illinois supreme court issued ruling allowing rahm',
#   'cluster': 21},
#  {'text': 'dont text drive', 'cluster': 104},
#  {'text': 'eric sharp hot spot ice fishing eric sharp detroit free press eric sharp wisp smelt vi',
#   'cluster': 60},
#  {'text': 'pensacola salt water fishing guide undoubtedly best tourist destination map unite',
#   'cluster': 60},
#  {'text': 'australian open men final andy murray novak djokovic',
#   'cluster': 71},
#  {'text': 'mann texting driving', 'cluster': 104},
#  {'text': 'dutch freeze contact iran hanging iranelection well late',
#   'cluster': 42},
#  {'text': 'viibryd approved treat depression adult psych central news',
#   'cluster': 58},
#  {'text': 'lady army health initiative model fitness nutrition mimi hall usa today time',
#   'cluster': 65},
#  {'text': 'pepsi max ad pepsi refresh message superbowl commercial',
#   'cluster': 99},
#  ...]

# %%
# construct tf-idf matrix
corpus = [d['text'] for d in data]
vectorizer = TfidfVectorizer(min_df=2, sublinear_tf=True)
X = vectorizer.fit_transform(corpus).todense()
tfidf_matrix = np.array(X)

# %%
# get labels of each tweet
labels = [d['cluster'] for d in data]

# %%
# K-Means clustering test
k_means = KMeans(n_clusters=max(labels), n_jobs=-1).fit(tfidf_matrix)
nmi = normalized_mutual_info_score(labels, k_means.labels_, average_method='arithmetic')
print('The NMI score of K-Means is:', nmi)
# Out:
# The NMI score of K-Means is: 0.8083287921393979

# %%
# Affinity propagation clustering test
ap = AffinityPropagation().fit(tfidf_matrix)
nmi = normalized_mutual_info_score(labels, ap.labels_, average_method='arithmetic')
print('The NMI score of Affinity propagation is:', nmi)
# Out:
# The NMI score of Affinity propagation is: 0.7733356331577484

# %%
# MeanShift clustering test
ms = MeanShift(bandwidth=0.44, bin_seeding=True, min_bin_freq=2, cluster_all=True, n_jobs=-1).fit(tfidf_matrix)
nmi = normalized_mutual_info_score(labels, ms.labels_, average_method='arithmetic')
print('The NMI score of MeanShift is:', nmi)
print('Its shape is:', np.unique(ms.labels_).shape)
# Out:
# The NMI score of MeanShift is: 0.6901183198703617
# Its shape is: (85,)

# %%
# SpectralClustering test
sc = SpectralClustering(n_clusters=max(labels)).fit(tfidf_matrix)
nmi = normalized_mutual_info_score(labels, sc.labels_, average_method='arithmetic')
print('The NMI score of Spectral Clustering is:', nmi)
# Out:
# The NMI score of SpectralClustering is: 0.698345651992622

# %%
# Ward hierarchical clustering test
whc = AgglomerativeClustering(n_clusters=max(labels), linkage='ward').fit(tfidf_matrix)
nmi = normalized_mutual_info_score(labels, whc.labels_, average_method='arithmetic')
print('The NMI score of Ward hierarchical clustering is:', nmi)
# Out:
# The NMI score of Ward hierarchical clustering is: 0.7864984641747731

# %%
# AgglomerativeClustering test
ac = AgglomerativeClustering(n_clusters=max(labels), affinity='cosine', linkage='single').fit(tfidf_matrix)
nmi = normalized_mutual_info_score(labels, ac.labels_, average_method='arithmetic')
print('The NMI score of Agglomerative Clustering with single linkage is:', nmi)
ac = AgglomerativeClustering(n_clusters=max(labels), affinity='cosine', linkage='average').fit(tfidf_matrix)
nmi = normalized_mutual_info_score(labels, ac.labels_, average_method='arithmetic')
print('The NMI score of Agglomerative Clustering with average linkage is:', nmi)
# Out:
# The NMI score of Agglomerative Clustering with single linkage is: 0.22496764238754718
# The NMI score of Agglomerative Clustering with average linkage is: 0.9003064131754916

# %%
# DBSCAN test
dbscan = DBSCAN(eps=0.1, n_jobs=-1).fit(tfidf_matrix)
nmi = normalized_mutual_info_score(labels, dbscan.labels_, average_method='arithmetic')
print('The NMI score of DBSCAN with eps=0.1 is:', nmi)
print('Its shape is:', np.unique(dbscan.labels_).shape)
dbscan = DBSCAN(eps=1, n_jobs=-1).fit(tfidf_matrix)
nmi = normalized_mutual_info_score(labels, dbscan.labels_, average_method='arithmetic')
print('The NMI score of DBSCAN with eps=1 is:', nmi)
print('Its shape is:', np.unique(dbscan.labels_).shape)
dbscan = DBSCAN(eps=2, n_jobs=-1).fit(tfidf_matrix)
nmi = normalized_mutual_info_score(labels, dbscan.labels_, average_method='arithmetic')
print('The NMI score of DBSCAN with eps=2 is:', nmi)
print('Its shape is:', np.unique(dbscan.labels_).shape)
# Out:
# The NMI score of DBSCAN with eps=0.1 is: 0.027537116536474605
# Its shape is: (5,)
# The NMI score of DBSCAN with eps=1 is: 0.568925646557483
# Its shape is: (64,)
# The NMI score of DBSCAN with eps=2 is: -8.557811214631876e-17
# Its shape is: (1,)

# %%
# Birch test
brc = Birch(n_clusters=max(labels)).fit(tfidf_matrix)
nmi = normalized_mutual_info_score(labels, brc.labels_, average_method='arithmetic')
print('The NMI score of Birch is:', nmi)
# Out:
# The NMI score of Birch is: 0.8050399281197088

# %%
# Gaussian mixtures test
gm_labels = GaussianMixture(n_components=max(labels), covariance_type='tied').fit_predict(tfidf_matrix)
nmi = normalized_mutual_info_score(labels, gm_labels, average_method='arithmetic')
print('The NMI score of Gaussian mixtures is:', nmi)
# Out:
# The NMI score of Gaussian mixtures is: 0.7987454617917258
